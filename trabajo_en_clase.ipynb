# %% [markdown]
# <a href="https://colab.research.google.com/github/CatalinaAcostaVProgramacion/Lenguajes_Programacion/blob/main/trabajo_en_clase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  # ***VALOR PRESENTE NETO***

# %% [markdown]
# El valor presente neto (VPN) es el valor de los flujos de efectivo proyectados, descontados al presente. Es un método de modelado financiero utilizado por los contadores para la elaboración de presupuestos de capital y por analistas e inversores para evaluar la rentabilidad de las inversiones y proyectos propuestos.

# %% [markdown]
# ### *¿Cómo calcular el valor presente neto?*

# %% [markdown]
# - Define el periodo.
# - Analiza el flujo de efectivo.
# - Ubica la tasa de descuento.
# - Aplica la fórmula y evalúa la rentabilidad del proyecto.

# %% [markdown]
# ####*Fórmula*

# %% [markdown]
# $$VPN = \sum_{t=0}^{n} \frac{C_t}{(1 + i)^t}$$

# %% [markdown]
# [LINK VALOR PRESENTE NETO](https://blog.hubspot.es/sales/que-es-valor-presente-neto#:~:text=Valor%20presente%20neto%20(VPN)%20%3D,la%20rentabilidad%20de%20una%20inversi%C3%B3n.)
